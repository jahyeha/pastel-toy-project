# %% [markdown]
# ## Bag of Words (BOW)

# %%
import re

def main():
    sentence = input("입력 > ")
    BOW_dict, BOW = create_BOW(sentence)
    print("\n=============Answer=============")
    print(BOW_dict)
    print(BOW)

def create_BOW(sentence):
    # test sentence = "Hello, my name is Pastel. Pastel has beautiful colors. What's your name?"
    print('\n* input sentence: {}\n'.format(sentence), '\t↓')
    bow_dict = {}
    bow = []
    s = sentence.lower()
    print("* lowered sentence: {}\n".format(s), '\t↓')
    splitted = re.sub(r'[^a-z]+', ' ', s).split() 
    print("* splitted sentence: ", splitted)
    
    cnt = 0
    print("\n--------------------------------------\n")
    for word in splitted:
        print("word: ", word)
        if len(word) < 1: 
            continue
        if word not in bow_dict:
            bow_dict[word] = cnt
            bow.append(0)
            cnt += 1
        bow[bow_dict[word]] += 1
        print('\t', bow_dict)
        print('\t', bow, '\n')
    return bow_dict, bow

if __name__ == "__main__":
    main()
# Out:
# 입력 > Hello, my name is Pastel. Pastel has beautiful colors. What's your name?
#
# * input sentence: Hello, my name is Pastel. Pastel has beautiful colors. What's your name?
#  	↓
# * lowered sentence: hello, my name is pastel. pastel has beautiful colors. what's your name?
#  	↓
# * splitted sentence:  ['hello', 'my', 'name', 'is', 'pastel', 'pastel', 'has', 'beautiful', 'colors', 'what', 's', 'your', 'name']
#
# --------------------------------------
#
# word:  hello
# 	 {'hello': 0}
# 	 [1]
#
# word:  my
# 	 {'hello': 0, 'my': 1}
# 	 [1, 1]
#
# word:  name
# 	 {'hello': 0, 'my': 1, 'name': 2}
# 	 [1, 1, 1]
#
# word:  is
# 	 {'hello': 0, 'my': 1, 'name': 2, 'is': 3}
# 	 [1, 1, 1, 1]
#
# word:  pastel
# 	 {'hello': 0, 'my': 1, 'name': 2, 'is': 3, 'pastel': 4}
# 	 [1, 1, 1, 1, 1]
#
# word:  pastel
# 	 {'hello': 0, 'my': 1, 'name': 2, 'is': 3, 'pastel': 4}
# 	 [1, 1, 1, 1, 2]
#
# word:  has
# 	 {'hello': 0, 'my': 1, 'name': 2, 'is': 3, 'pastel': 4, 'has': 5}
# 	 [1, 1, 1, 1, 2, 1]
#
# word:  beautiful
# 	 {'hello': 0, 'my': 1, 'name': 2, 'is': 3, 'pastel': 4, 'has': 5, 'beautiful': 6}
# 	 [1, 1, 1, 1, 2, 1, 1]
#
# word:  colors
# 	 {'hello': 0, 'my': 1, 'name': 2, 'is': 3, 'pastel': 4, 'has': 5, 'beautiful': 6, 'colors': 7}
# 	 [1, 1, 1, 1, 2, 1, 1, 1]
#
# word:  what
# 	 {'hello': 0, 'my': 1, 'name': 2, 'is': 3, 'pastel': 4, 'has': 5, 'beautiful': 6, 'colors': 7, 'what': 8}
# 	 [1, 1, 1, 1, 2, 1, 1, 1, 1]
#
# word:  s
# 	 {'hello': 0, 'my': 1, 'name': 2, 'is': 3, 'pastel': 4, 'has': 5, 'beautiful': 6, 'colors': 7, 'what': 8, 's': 9}
# 	 [1, 1, 1, 1, 2, 1, 1, 1, 1, 1]
#
# word:  your
# 	 {'hello': 0, 'my': 1, 'name': 2, 'is': 3, 'pastel': 4, 'has': 5, 'beautiful': 6, 'colors': 7, 'what': 8, 's': 9, 'your': 10}
# 	 [1, 1, 1, 1, 2, 1, 1, 1, 1, 1, 1]
#
# word:  name
# 	 {'hello': 0, 'my': 1, 'name': 2, 'is': 3, 'pastel': 4, 'has': 5, 'beautiful': 6, 'colors': 7, 'what': 8, 's': 9, 'your': 10}
# 	 [1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 1]
#
#
# =============Answer=============
# {'hello': 0, 'my': 1, 'name': 2, 'is': 3, 'pastel': 4, 'has': 5, 'beautiful': 6, 'colors': 7, 'what': 8, 's': 9, 'your': 10}
# [1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 1]

# %% [markdown]
# ----------------------------------------------
# ## Bag of Words - Practice

# %%
import re

def main():
    sentence = input("입력 > ")
    BOW_dict, BOW = create_BOW(sentence)
    print("\n=============Answer=============")
    print(BOW_dict)
    print(BOW)

def create_BOW(sentence):
    '''
    bow_dict과 bow를 return하는 create_BOW 함수를 완성해보세요!
    '''
    
    
    return bow_dict, bow

if __name__ == "__main__":
    main()
